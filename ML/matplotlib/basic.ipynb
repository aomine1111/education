# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,10)
y = 2 * x
plt.plot(x,y)
plt.title("Название гррафика")
plt.xlabel("Ось x")
plt.ylabel("Ось y")
plt.xlim(0,6)
plt.ylim(0,10)
plt.show()
plt.savefig("my_first_profeck om matprop.jpg")
