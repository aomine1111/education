# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,10)
y = 2 * x
a = np.linspace(0,10,11)
b = a ** 4

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**3, label = "x**3")
ax.plot(x,x**2, label = "x**3")
ax.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,10)
y = 2 * x
a = np.linspace(0,10,11)
b = a ** 4

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**3, label = "x**3")
ax.plot(x,x**2, label = "x**3")
ax.legend(loc=1)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,10)
y = 2 * x
a = np.linspace(0,10,11)
b = a ** 4

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**3, label = "x**3")
ax.plot(x,x**2, label = "x**3")
ax.legend(loc=3)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,10)
y = 2 * x
a = np.linspace(0,10,11)
b = a ** 4

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**3, label = "x**3")
ax.plot(x,x**2, label = "x**3")
ax.legend(loc=4)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,10)
y = 2 * x
a = np.linspace(0,10,11)
b = a ** 4

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**3, color="blue", linewidth=0.25, marker='+', ms=10, label="x**3")
ax.plot(x, x**2, '--', color="#8B008B", marker='o', ms=8, label="x**2")

ax.legend(loc=1) 
plt.show()
