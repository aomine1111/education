# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\aomin\Downloads\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V11 (1)\05-Seaborn\dm_office_sales.csv")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   division            1000 non-null   object
#  1   level of education  1000 non-null   object
#  2   training level      1000 non-null   int64
#  3   work experience     1000 non-null   int64
#  4   salary              1000 non-null   object
#  5   sales               1000 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 47.0+ KB

# %%
sns.scatterplot(x='salary',y='sales',data=df)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary',y='sales',data=df, hue="division")
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary',y='sales',data=df, hue="work experience")
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary',y='sales',data=df, hue="work experience",palette='viridis',size='work experience')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary', y='sales', data=df, s=500)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary', y='sales', data=df, s=500,linewidth=0,alpha=0.2)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary', y='sales', data=df, style= "level of education")
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary', y='sales', data=df, style= "level of education",hue='level of education')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>
